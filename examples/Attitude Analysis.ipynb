# %%
import px4tools
import datetime
import os

# %pylab inline
rcParams['lines.linewidth'] = 3
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = px4tools.ulog2pandas(os.path.join(os.environ['HOME'],
    '.ros/rootfs/fs/microsd/log/2016-11-28/17_23_35.ulg'))

# %%
plt.figure(figsize=(10, 10))
px4tools.ulog.plot_euler_angles(df)
armed_times = df.t_vehicle_status_0.index[
    np.argwhere(df.t_vehicle_status_0.f_arming_state == 2)][:,0]
t1 = armed_times[0]
t2 = armed_times[-26]
plt.gca().set_xlim([t1, t2]);

# %%
plt.figure(figsize=(10, 10))
px4tools.ulog.plot_quaternions(df)
plt.gca().set_xlim([t1, t2])

plt.figure(figsize=(10, 10))
px4tools.ulog.plot_quaternion_normal(df)
plt.gca().set_xlim([t1, t2])
# Out:
# (719163.0003759792, 719163.0004180804)
