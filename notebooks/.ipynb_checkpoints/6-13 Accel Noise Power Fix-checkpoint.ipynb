# %%
import pandas
import px4tools
import pylab as pl
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
pl.figure(figsize=(10,10))
data_fixed2 = px4tools.process_data(pandas.read_csv('log/2015-06-13/16_16_46.csv'))
px4tools.pos_analysis(data_fixed2);
pl.axis('equal')
# Out:
# (-2.0, 10.0, -10.0, 20.0)

# %%
pl.figure(figsize=(10,10))
data_fixed3 = px4tools.process_data(pandas.read_csv('log/2015-06-13/16_13_38.csv'))
px4tools.pos_analysis(data_fixed3);
pl.axis('equal')
# Out:
# (-6.0, 3.0, -5.0, 35.0)

# %%
data_fixed2.GPOS_VelD.plot(legend=True)
data_fixed2.GPS_VelD.plot()

# %%
px4tools.alt_analysis(data_fixed2);

# %%
pl.figure(figsize=(10,10))
data4 = px4tools.process_data(pandas.read_csv('log/2015-06-13/16_49_12.csv'))
px4tools.pos_analysis(data4);
pl.axis('equal')
# Out:
# (-6.0, 10.0, -10.0, 4.0)

# %%
pl.figure(figsize=(15,10))
data4[10:100].GPOS_VelD.plot(legend=True)
data4[10:100].GPS_VelD.plot()
