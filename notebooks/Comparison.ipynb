# %%
import pandas
import px4tools
import pylab as pl

# %matplotlib inline

pl.rcParams['figure.figsize'] = (15,5)

# %%
data_lpe = px4tools.project_lat_lon(px4tools.process_data(pandas.read_csv('log/comparison/lpe.csv')))

# %%
data_inav = px4tools.project_lat_lon(px4tools.process_data(pandas.read_csv('log/comparison/inav.csv')))

# %%
px4tools.plot_position_loops(data_lpe)

# %%
px4tools.plot_position_loops(data_inav)

# %%
px4tools.plot_velocity_loops(data_lpe)

# %%
px4tools.plot_velocity_loops(data_inav)

# %%
data_lpe_1 = data_lpe[20:25]
data_lpe_1.LPOS_VX.plot()
data_lpe_1.LPOS_VY.plot()
data_lpe_1.LPOS_VZ.plot()

#data_lpe.LPOS_VY.plot()
data_lpe_1.ATSP_PitchSP.plot()

# %%
# px4tools.plot_attitude_rate_loops(data_lpe)

# %%
px4tools.plot_attitude_rate_loops(data_inav[2000:2500])
