# %%
import px4tools
import pandas
import pylab as pl
# %matplotlib inline
pl.rcParams['figure.figsize'] = (15,15)

# %%
data = px4tools.project_lat_lon(px4tools.process_data(pandas.read_csv('log/new_deriv.csv')))

# %%
px4tools.plot_attitude_rate_loops(data)
